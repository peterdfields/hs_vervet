# %%
import os
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv(os.path.expanduser("~/vervet_project/analyses/20140203_UnifiedGenotyper_African_Chlorocebus/_data/GATK_UnifiedGenotyper_163NonVRC_Chlorocebus_snp_CAE28_filter.tsv"),sep='\t')

# %%
def can_convert(snp):
    try:
        int(snp)
        return True
    except:
        return False

# %%
bi_df = df[df['AC'].apply(can_convert)]

# %%
bi_df['AC'] = bi_df['AC'].apply(int)

# %%
bi_df['DP'].mean()
# Out:
# 1389.3539297003756

# %%
len(bi_df)
# Out:
# 37013

# %%
len(bi_df[bi_df["FILTER"]=="PASS"])
# Out:
# 22128

# %%
bi_df.ix[:50]
# Out:
#     CHROM      POS       QUAL                               FILTER   AC  \
# 0   CAE28  1000030     281.02             ExCov,MQ0_10pct,ExRawCov    4
# 1   CAE28  1000058     117.30                       ExCov,ExRawCov    6
# 2   CAE28  1000059     161.68            ExCov,ExRawCov,StrandBias    4
# 3   CAE28  1000060     297.78                       ExCov,ExRawCov    6
# 4   CAE28  1000069  233892.07             ExCov,MQ0_10pct,ExRawCov  161
# 5   CAE28  1000071   19660.66  ExCov,MQ0_10pct,ExRawCov,StrandBias   93
# 6   CAE28  1000111  111147.44             ExCov,MQ0_10pct,ExRawCov  163
# 8   CAE28  1000122   97457.75             ExCov,MQ0_10pct,ExRawCov  158
# 9   CAE28  1000127     742.32             ExCov,MQ0_10pct,ExRawCov   14
# 10  CAE28  1000132  105926.85             ExCov,MQ0_10pct,ExRawCov  160
# 11  CAE28  1000133   66515.99             ExCov,MQ0_10pct,ExRawCov  145
# 12  CAE28  1000144     187.16             ExCov,MQ0_10pct,ExRawCov    5
# ...

# %%
len(bi_df["DP"][bi_df["FILTER"]=="PASS"])
# Out:
# 22128

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 4))
print axes
stat = ['DP',"MQ","MQ0"] 
for i,var in enumerate(stat):
    bi_df[var].hist(ax=axes[0][i],bins=500)
    axes[0][i].set_title(var)
for i,var in enumerate(stat):
    bi_df[var][bi_df["FILTER"]=="PASS"].hist(ax=axes[1][i],bins=500)
    #axes[i].set_title(var)
for ax in axes:
    ax[0].set_ylim([0,1000])
    ax[0].set_xlim([0,5000])
    ax[2].set_ylim([0,2000])
    ax[2].set_xlim([0,1000])
# Out:
# [[Axes(0.125,0.547727;0.227941x0.352273)
#   Axes(0.398529,0.547727;0.227941x0.352273)
#   Axes(0.672059,0.547727;0.227941x0.352273)]
#  [Axes(0.125,0.125;0.227941x0.352273)
#   Axes(0.398529,0.125;0.227941x0.352273)
#   Axes(0.672059,0.125;0.227941x0.352273)]]

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
stats = ['DP',"MQ","MQ0"] 
for i,var in enumerate(stats):
    bi_df[var].hist(ax=axes[i],bins=500)
    axes[i].set_title(var)
axes[0].set_ylim([0,1000])
axes[0].set_xlim([0,5000])
axes[2].set_ylim([0,2000])
axes[2].set_xlim([0,1000])
# Out:
# (0, 1000)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 4))
bi_df["HaplotypeScore"].hist(ax=axes,bins=500)
axes.set_ylim([0,1000])
axes.set_xlim([0,50])
# Out:
# (0, 50)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 4))
bi_df["FS"].hist(ax=axes,bins=500)
axes.set_ylim([0,3000])
axes.set_xlim([0,300])
# Out:
# (0, 300)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 4))
bi_df["ReadPosRankSum"].hist(ax=axes,bins=500)
axes.set_ylim([0,600])
axes.set_xlim([-20,20])
# Out:
# (-20, 20)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 4))
bi_df["QUAL"].hist(ax=axes,bins=2000)
axes.set_ylim([0,1000])
axes.set_xlim([10,10000])
# Out:
# (10, 10000)

# %%
x = stats.uniform(loc=0.1,scale=0.9)

# %%
dir(x)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'args',
#  'cdf',
#  'dist',
#  'entropy',
#  'interval',
#  'isf',
#  'kwds',
#  'mean',
#  'median',
#  'moment',
#  'pdf',
#  'pmf',
#  'ppf',
#  'rvs',
#  'sf',
#  'stats',
#  'std',
#  'var']

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))
stats.probplot(bi_df["QUAL"].apply(lambda x: 10**(-x/10.)), dist="uniform(loc=0.,scale=0.1)", plot=pylab)
axes.set_ylim([0,0.1])
axes.set_xlim([0,0.1])
plot([0,1],[0,1])

# %%
bi_df["QUAL"].apply(lambda x: 10**(-x/10.)).hist(bins=1000)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))
stats.probplot(bi_df["DP"], dist="norm(loc=1300,scale=sqrt(1300))", plot=pylab)
#axes.set_ylim([0,0.02])
axes.set_xlim([1100,1400])
plot([0,2000],[0,2000])

# %%
bi_df["DP"].hist()

# %%
fig = plt.figure()
sub = fig.add_subplot(211)
pic = stats.probplot(randn(100), dist="norm", plot=pylab)
#sub.set_ylim([0,10000])

# %%
df.head()
# Out:
#    CHROM      POS       QUAL                     FILTER   AC     MQ   MQ0  \
# 0  CAE28  1000030     281.02   ExCov,MQ0_10pct,ExRawCov    4  39.73  3969
# 1  CAE28  1000058     117.30             ExCov,ExRawCov    6  46.88  1434
# 2  CAE28  1000059     161.68  ExCov,ExRawCov,StrandBias    4  46.94  1425
# 3  CAE28  1000060     297.78             ExCov,ExRawCov    6  46.66  1555
# 4  CAE28  1000069  233892.07   ExCov,MQ0_10pct,ExRawCov  161  38.98  3873
#
#       DP    QD       FS  HaplotypeScore  MQRankSum  ReadPosRankSum
# 0  36430  0.30   23.021        134.5611     21.849           4.804
# 1  33630  0.10  112.919        132.8229    -61.336          22.508
# 2  34028  0.21  477.580        153.9838    -59.305          29.403
# 3  34655  0.24  102.582        169.3982    -62.068          16.816
# 4  35233  6.70    2.473        142.1379    -42.430           3.455

# %%
junk100 = lambda x: x // 100

# %%
test = pd.DataFrame({"X":rand(2324)})
