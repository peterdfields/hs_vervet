# %%
# %matplotlib inline

# %%
#%%px --local
#Global init
import os
import pandas as pd
import numpy as np
import scipy
from numpy import *
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams["font.size"]=14
eu = os.path.expanduser
jn = os.path.join
meta_dir = eu("~/vervet_project/metadata")
var_ana_dir = eu("~/vervet_project/analyses/20140403_UnifiedGenotyper_ref3500_non_VRC/_data")
manuscript_dir = eu("~/vervet_project/manuscript/163_pop_manuscript/")
man_ana_dir = eu("~/vervet_project/analyses/20140607_vervetpopgen_manuscript/_data")
pops = ["aet","cyn","pyn","pys","sab","tan"]
colors = ["blue","magenta","cyan","green","orange","red"]
pops2 = ["aet","cyn","pyn","pys","sab","sac","tan"]
colors2 = ["blue","magenta","cyan","green","orange","yellow","red"]
#alternative colors, are those better?
#colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k'] #=mpl.rcParams['axes.color_cycle'][:7]
meta_df = pd.read_csv(jn(meta_dir,"163_population_ucla_id_taxon.csv"),index_col=0)
meta_df["index"] = meta_df.index
if float(".".join(pd.__version__.split(".")[0:2])) >= 0.14:
    meta_df.drop_duplicates(subset='index', take_last=True, inplace=True)
else:
    meta_df.drop_duplicates(cols='index', take_last=True, inplace=True)
del meta_df["index"]
ucla_ids = meta_df.index.unique()
chrom_length = pd.read_csv(eu("~/vervet_project/metadata/ref3500.tsv"),sep="\t",index_col=0,squeeze=True,header=None)
autosomes = ["CAE" + str(i) for i in range(1,30)]
chromosomes = ["CAE" + str(i) for i in range(1,30)+["X","Y"]]
#genetic map for colony SNPs
map_fn = eu("~/vervet_project/data/map/vervet.map")
map_s = pd.read_csv(map_fn,usecols=[1,2,4],index_col=[0,1],squeeze=True)
map_s.index = pd.MultiIndex.from_tuples([("CAE"+str(x[0]),x[1]) for x in map_s.index])
#gene annotations (2 alternative versions)
def annot_cols_for_attributes(annot_df):
    def attribute_dic(attr):
        attr_ls = [x.split(' "') for x in [el for el in attr.split('"; ') if el != " "]]
        attr_dic = {el[0]:el[1] for el in attr_ls}
        return attr_dic
    def get_value(dic,key):
        try:
            return dic[key]
        except KeyError:
            return np.nan
    annot_df["attribute"] =  annot_df["attribute"].apply(attribute_dic)
    keys = set().union(*[el.keys() for el in annot_df["attribute"]])
    for k in keys:
        annot_df[k] = annot_df["attribute"].apply(lambda dic: get_value(dic,k))
    del annot_df["attribute"]
    return annot_df
annot_dir = eu("~/vervet_project/data/annotation/Chlorocebus_sabaeus_1_1")
annot_mike_header = ["chrom","source","feature","start","end","score","strand","frame","attribute"]
annot_mike = pd.read_csv(jn(annot_dir,
                            "ref_Chlorocebus_sabeus_1.1_top_level.coding_only."
                            "CHR_ALL.CLEAN.UNIQ_CAE.gtf"),
                         sep="\t",header=False,names=annot_mike_header)
annot_mike = annot_cols_for_attributes(annot_mike)
annot_mike.index = pd.MultiIndex.from_tuples(zip(annot_mike["chrom"],annot_mike["start"]))
#annot_20140703 = pd.read_csv(jn(annot_dir,
#                            "ref_Chlorocebus_sabeus_1.1_top_level.20140703_CAE.gtf"),
#                         sep="\t",header=False,names=annot_mike_header)
#annot_20140703 = annot_cols_for_attributes(annot_20140703)
#annot_20140703.index = pd.MultiIndex.from_tuples(zip(annot_20140703["chrom"],annot_20140703["start"]))
def make_gene_df(annot_df):
    idx_tuples = []
    ends = []
    names = []
    transcript_ids = []
    protein_ids = []
    for n, df in annot_df.groupby("gene_id",sort=False):
        idx_tuples.append((df.index[0][0],df["start"].min()))
        ends.append(df["end"].max())
        names.append(n)
        transcript_ids.append(df.iloc[0]["transcript_id"])
        protein_ids.append(df[df["feature"]=="CDS"].iloc[0]["protein_id"])
    gene_df = pd.DataFrame({"end":ends,"gene_id":names,"transcript_id":transcript_ids,"protein_id":protein_ids},
                       index=pd.MultiIndex.from_tuples(idx_tuples))
    gene_df.index.names = ["chrom","pos"]
    return gene_df
#gene_df.to_csv(jn(meta_dir,"annot_mike_genes.tsv"),sep="\t")
gene_df = pd.read_csv(jn(meta_dir,"annot_mike_genes.tsv"),sep="\t",index_col = [0,1])

# %% [markdown]
# ## Fst

# %% [markdown]
# ## PCAdapt

# %%
with open(jn(var_ana_dir,"UGr_163_ref3500_ref_alt_pcadapt_all_chrom.header")) as f:
    individuals = f.readline().strip().split("\t")

# %%
pcad_df = pd.read_csv(jn(man_ana_dir,"pcadapt_CAE28_K6"),sep="[ \t]",engine='python')
scores = pd.read_csv(jn(man_ana_dir,"pcadapt_CAE28_K6_scores"),sep=" ",header=False,names=individuals,index_col=False)

# %%
scores
# Out:
#       A8518      AG23    AG5417    AGM126    AGM127    AGM129    AGM130  \
# 0  0.008586  0.013296  0.013583 -0.030809 -0.032804 -0.033793 -0.032484
# 1  0.014246 -0.024394 -0.036200 -0.264611 -0.275756 -0.285388 -0.267783
# 2 -0.001199 -0.142335 -0.255032  0.047208  0.050145  0.051932  0.045314
# 3  0.075172 -0.006500 -0.014080 -0.008230 -0.006823 -0.006845 -0.010910
# 4 -0.000031  0.236916  0.584218 -0.016188 -0.014364 -0.020222 -0.015464
#
#      AGM131    AGM136    AGM137    ...      VZC1017   VZC1018   VZC1020  \
# 0 -0.031648 -0.032181 -0.031287    ...     0.042992  0.045540  0.041132
# 1 -0.277948 -0.283653 -0.257721    ...     0.006183  0.008851  0.008867
# 2  0.048550  0.050443  0.038666    ...    -0.165175 -0.162171 -0.123337
# 3 -0.005496 -0.010172 -0.011639    ...    -0.002329 -0.002147 -0.001150
# 4 -0.017931 -0.019494 -0.011497    ...    -0.165203 -0.173572 -0.122940
#
#        W566      X186      X336      X598      Y010      Y083      Y173
# 0  0.008791  0.007260  0.008221  0.007680  0.008608  0.007963  0.008164
# 1  0.015235  0.007680  0.013952  0.009565  0.016487  0.013037  0.013147
# 2  0.001336  0.002712  0.001929  0.002628  0.003629  0.002890  0.003300
# 3 -0.046723 -0.059759 -0.049050 -0.051836 -0.085853 -0.062191 -0.066927
# 4 -0.000752 -0.000841 -0.000109 -0.000751 -0.001328 -0.000781 -0.001488
#
# [5 rows x 163 columns]

# %%
pcad_df["max"].plot(style=".", markersize=5, ax=ax)

# %%
K = len(scores.index)
fig = plt.figure(figsize=(20,3*K))
for i in scores.index:
    ax = fig.add_subplot(K,1,i)
    scores.T[i].plot(style=".", markersize=5, ax=ax)

# %%
plt.scatter(scores.T[0],scores.T[1])

# %%
plt.scatter(scores.T[2],scores.T[3])

# %%
plt.scatter(scores.T[4],scores.T[5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-ff497afcc783> in <module>()
# ----> 1 plt.scatter(scores.T[4],scores.T[5])
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1682             return self._getitem_multilevel(key)
#    1683         else:
# -> 1684             return self._getitem_column(key)
#    1685
#    1686     def _getitem_column(self, key):
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1689         # get column
#    1690         if self.columns.is_unique:
# -> 1691             return self._get_item_cache(key)
#    1692
#    1693         # duplicate columns & possible reduce dimensionaility
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2535
#    2536             if not isnull(item):
# -> 2537                 loc = self.items.get_loc(item)
#    2538             else:
#    2539                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3353)()
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3233)()
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6540)()
#
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6484)()
#
# KeyError: 5
