# %%
# %matplotlib inline

# %%
import os, json
import pandas as pd
import numpy as np
import scipy
import pickle
#from numpy import *
import matplotlib as mpl
from matplotlib import pyplot as plt
eu = os.path.expanduser
jn = os.path.join
mpl.rcParams["font.size"]=14
eu = os.path.expanduser
jn = os.path.join
meta_dir = eu("~/vervet_project/metadata")
var_ana_dir = eu("~/vervet_project/analyses/20140403_UnifiedGenotyper_ref3500_non_VRC/_data")

# %%
import ast
def str_to_dic(s):
    try:
        return ast.literal_eval(s)
    except ValueError:
        print s
        raise
mt = pd.read_csv(jn(meta_dir,"163_master_table.csv"),
                 index_col=0,
                 converters={"library":str_to_dic,"phenotypes":str_to_dic}
                 )

# %%
chrom = "CAE8"
ibd_df = pd.read_csv(jn(var_ana_dir,"GATK_UG_163NonVRC_ref3500_snp_{}_excluding_filtered2_beagle2.ibd".format(chrom)),
                     sep="\t",names=["id0","strd0","id1","strd1","chrom","start","end","lod"])

# %%
mt[mt["species"]=="Chlorocebus tantalus"]
# Out:
#                           country orig_quality_format               species  \
# ucla_id
# AGM126   Central African Republic             phred33  Chlorocebus tantalus
# AGM127   Central African Republic             phred33  Chlorocebus tantalus
# AGM129   Central African Republic             phred33  Chlorocebus tantalus
# AGM130   Central African Republic             phred33  Chlorocebus tantalus
# AGM131   Central African Republic             phred33  Chlorocebus tantalus
# AGM136   Central African Republic             phred33  Chlorocebus tantalus
# AGM137   Central African Republic             phred33  Chlorocebus tantalus
# AGM141   Central African Republic             phred33  Chlorocebus tantalus
# AGM142   Central African Republic             phred33  Chlorocebus tantalus
# AGM143   Central African Republic             phred33  Chlorocebus tantalus
# AGM144   Central African Republic             phred33  Chlorocebus tantalus
#
#         phenotypes  age  age_cas age_approx  longitude  latitude  coverage  \
# ucla_id
# AGM126          {}  NaN      NaN        NaN  18.583333  4.366667       4.1
# AGM127          {}  NaN      NaN        NaN  18.583333  4.366667       4.5
# AGM129          {}  NaN      NaN        NaN  18.583333  4.366667       4.7
# AGM130          {}  NaN      NaN        NaN  18.583333  4.366667       4.6
# AGM131          {}  NaN      NaN        NaN  18.583333  4.366667       4.8
# AGM136          {}  NaN      NaN        NaN  18.583333  4.366667       4.5
# AGM137          {}  NaN      NaN        NaN  18.583333  4.366667       4.6
# AGM141          {}  NaN      NaN        NaN  18.583333  4.366667      10.1
# AGM142          {}  NaN      NaN        NaN  18.583333  4.366667       4.8
# AGM143          {}  NaN      NaN        NaN  18.583333  4.366667       4.0
# AGM144          {}  NaN      NaN        NaN  18.583333  4.366667       4.8
#
#                                                    library
# ucla_id
# AGM126   {u'gerald_D0YKWACXX_8_AAGCGA': {u'path_mate1_p...
# AGM127   {u'gerald_D0YRKACXX_4_CTAGCT': {u'path_mate1_p...
# AGM129   {u'gerald_C0RDDACXX_7_GGCCTG': {u'path_mate1_p...
# AGM130   {u'gerald_D0YRKACXX_1_GACGGA': {u'path_mate1_p...
# AGM131   {u'gerald_C0RDDACXX_5_GTAGAG': {u'path_mate1_p...
# AGM136   {u'gerald_D0YRKACXX_2_GCTCCA': {u'path_mate1_p...
# AGM137   {u'gerald_D0YRKACXX_5_TCGGCA': {u'path_mate1_p...
# AGM141   {u'gerald_6286GAAXX_7': {u'path_mate1_phred33'...
# AGM142   {u'gerald_C0RDDACXX_4_TATAAT': {u'path_mate1_p...
# AGM143   {u'gerald_D0YRKACXX_2_CTATAC': {u'path_mate1_p...
# AGM144   {u'gerald_D0YRKACXX_4_CCTTAG': {u'path_mate1_p...

# %%
ghana = "VGHA1001"
tan = "AGM141"

# %%
species = ["_".join(sorted(s)) for s in  zip(mt.ix[ibd_df["id0"]]["species"].values,mt.ix[ibd_df["id1"]]["species"].values)]
ibd_df["species"] = species
ibd_df["country"] = ["_".join(sorted(s)) for s in  zip(mt.ix[ibd_df["id0"]]["country"].values,mt.ix[ibd_df["id1"]]["country"].values)]

# %%
ibd_df["sp0"] = [s for s in  mt.ix[ibd_df["id0"]]["pop3"].values]
ibd_df["sp1"] = [s for s in  mt.ix[ibd_df["id1"]]["pop3"].values]

# %%
pop3_group = ibd_df.groupby(["sp0","sp1"])

# %%
l = pop3_group.apply(lambda x: len(x)).unstack().fillna(0)
l = (l+l.T)
l_df = pd.DataFrame(np.triu(l.values),index=l.index,columns=l.columns)
vc = mt["pop3"].value_counts()
#this is the number of individual pairs, makes a small error for diagonal entries
normalisation = pd.DataFrame(np.outer(vc.values,vc.values)/2,index=vc.index,columns=vc.index)
(l_df/normalisation).applymap(round)
# Out:
#      aet  cyn  pyn  pys   sab   sac   sar  tan
# aet  667    5   12    4     1     1     1    7
# cyn    0  292   48   96     2     2     1    7
# pyn    0    0  162   36     3     3     2   13
# pys    0    0    0  471     1     2     1    5
# sab    0    0    0    0  1085  1094   934   10
# sac    0    0    0    0     0  3413  1733   13
# sar    0    0    0    0     0     0  2405    8
# tan    0    0    0    0     0     0     0  200

# %%
ibd_df["c0"] = [s for s in  mt.ix[ibd_df["id0"]]["country"].values]
ibd_df["c1"] = [s for s in  mt.ix[ibd_df["id1"]]["country"].values]

# %%
country_group = ibd_df.groupby(["c0","c1"])

# %%
l = country_group.apply(lambda x: len(x)).unstack().fillna(0)
l = (l+l.T)
#l = pd.DataFrame(np.triu(l.values),index=l.index,columns=l.columns)
vc = mt["country"].value_counts()
#this is the number of individual pairs, makes a small error for diagonal entries
normalisation = pd.DataFrame(np.outer(vc.values,vc.values)/2,index=vc.index,columns=vc.index)
(l/normalisation).applymap(round)
# Out:
#                           Barbados  Botswana  Central African Republic  \
# Barbados                      2405         1                         8
# Botswana                         1       125                         8
# Central African Republic         8         8                       200
# Ethiopia                         1         3                         7
# Gambia                         953         1                         8
# Ghana                          723         3                        29
# Kenya                            2        46                        15
# Nevis                         1598         1                        15
# Saint Kitts                   1808         2                        13
# South Africa                     1       177                         5
# Tanzania                         1        42                         7
# Zambia                           1       148                         7
#
#                           Ethiopia  Gambia  Ghana  Kenya  Nevis  Saint Kitts  \
# Barbados                         1     953    723      2   1598         1808
# Botswana                         3       1      3     46      1            2
# Central African Republic         7       8     29     15     15           13
# Ethiopia                       667       1      2     15      1            1
# Gambia                           1    1162    693      3   1099         1123
# Ghana                            2     693    481      4    829          882
# Kenya                           15       3      4    186      3            3
# Nevis                            1    1099    829      3   4160         3151
# Saint Kitts                      1    1123    882      3   3151         3477
# South Africa                     4       1      2     40      2            2
# Tanzania                         8       2      7    160      1            1
# Zambia                           5       2      4     54      2            2
#
#                           South Africa  Tanzania  Zambia
# Barbados                             1         1       1
# Botswana                           177        42     148
# Central African Republic             5         7       7
# Ethiopia                             4         8       5
# Gambia                               1         2       2
# Ghana                                2         7       4
# Kenya                               40       160      54
# Nevis                                2         1       2
# Saint Kitts                          2         1       2
# South Africa                       495        27      94
# Tanzania                            27        70      36
# Zambia                              94        36     292

# %%
Conclusion: Central African republic shares more with Ghana than with Gambia -> Signal of migration!?

# %%
ibd_df["length"] = ibd_df["end"] -ibd_df["start"]

# %%
ibd_df["length"].hist(bins=500)

# %%
import random

# %%
plt.scatter(ibd_df["length"],ibd_df["lod"])

# %%
small_df = ibd_df.ix[random.sample(ibd_df.index, 1000)]

# %%
country_pair_ls = list(small_df["country"].unique())

# %%
plt.scatter(small_df["length"],small_df["lod"],
            c=small_df["country"].apply(lambda x: country_pair_ls.index(x)*1./len(country_pair_ls)))

plt.legend()
# Out:
# /net/gmi.oeaw.ac.at/nordborg/user/hannes.svardal/Documents/Dropbox/Akademisches/lib/python/virtualenvs/ver/lib/python2.7/site-packages/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "
